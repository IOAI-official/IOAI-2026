# %% [markdown]
# # Dataset viewer
#
# Change `SPLIT` and `INDEX` to inspect another independent snapshot. Row 0 is at the top and column 0 is at the left.

# %%
from visualization import show_scene

SPLIT = "train"       # "train" or "test_public"
INDEX = 0               # train: 0–59999, test_public: 0–3599

show_scene(SPLIT, INDEX)
